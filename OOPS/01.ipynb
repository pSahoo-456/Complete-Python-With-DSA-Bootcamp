# %% [markdown]
# # Class and Object
#
# object-oriented programming is a programming paradigram that uses "objects" to design applications and computer programs. OOP allows for modeling real world scenarios using classes and objects . This lesson covers the basics of creating classes and objects , including instance variables and methods.

# %%
# Class : is a blueprint for creating objects. It defines a set of attributes and methods that the created objects will have.
class Car:
   pass

audi=Car()
bmw=Car()

print(type(audi))

print(audi)
# Out:
# <class '__main__.Car'>
# ...

# %%
# Instance Variables : are variables that are defined within a class and are unique to each instance of that class.
class Dog:
    #constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age
dog1 = Dog("Buddy", 3)
dog2 = Dog("Max", 5)

print(dog1)
print(dog1.name)
print(dog2.age)
# Out:
# ...
# Buddy
# 5

# %%
## Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        return f"{self.name} says Woof!"

    def get_age(self):
        return self.age
    
dog:Dog = Dog("Buddy", 3)
print(dog.bark())
# Out:
# Buddy says Woof!

# %%
### Modeling a Bank Account
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposit(self,amoumnt):
        self.balance+=amoumnt
        print(f"Deposit of {amoumnt} made. New balance is {self.balance}")
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds")
        else:
            self.balance-=amount
            print(f"Withdrawal of {amount} made. New balance is {self.balance}")
        
        def get_balance(self):
            return self.balance
    
#create an account
account=BankAccount("Prakash Sahoo",3000)
print(account.balance)
# Out:
# 3000

# %%
## Call instance methods
account.deposit(1500)
account.withdraw(500)
# Out:
# Deposit of 1500 made. New balance is 4500
# Withdrawal of 500 made. New balance is 4000
